# %%
import pandas as pd

# Define data for top air purifier brands in India
data = {
    'Brand': ['Dyson', 'Philips', 'Xiaomi', 'Coway', 'Honeywell', 'Sharp'],
    'Model': ['Purifier Cool', 'Series 3000i', 'Air Purifier 4', 'AirMega 150', 'Air Touch V3', 'FP-F40E'],
    'Price (INR)': [39900, 21995, 12999, 14990, 11990, 17990],
    'Filtration Stages': ['HEPA + Carbon + UV', 'HEPA + Carbon', 'HEPA + Carbon', 'HEPA + Pre-filter', 'HEPA + Carbon', 'HEPA + Plasma Cluster'],
    'Smart Features': ['App, Wi-Fi, AQI Display', 'App, Display', 'App, AQI Display', 'AQI Display Only', 'Display Only', 'No Smart Features'],
    'Coverage Area (sq ft)': [600, 570, 516, 355, 450, 320],
    'Warranty': ['2 Years', '2 Years', '1 Year', '5 Years', '1 Year', '1 Year']
}

# Create DataFrame
df = pd.DataFrame(data)

# Export to CSV
df.to_csv('AirPurifier_Competitor_FeatureMatrix.csv', index=False)

# Preview
df.head()
# Out:
#        Brand           Model  Price (INR)   Filtration Stages  \
# 0      Dyson   Purifier Cool        39900  HEPA + Carbon + UV
# 1    Philips    Series 3000i        21995       HEPA + Carbon
# 2     Xiaomi  Air Purifier 4        12999       HEPA + Carbon
# 3      Coway     AirMega 150        14990   HEPA + Pre-filter
# 4  Honeywell    Air Touch V3        11990       HEPA + Carbon
#
#             Smart Features  Coverage Area (sq ft) Warranty
# 0  App, Wi-Fi, AQI Display                    600  2 Years
# 1             App, Display                    570  2 Years
# 2         App, AQI Display                    516   1 Year
# 3         AQI Display Only                    355  5 Years
# 4             Display Only                    450   1 Year

# %%
from google.colab import files

files.download('AirPurifier_Competitor_FeatureMatrix.csv')
